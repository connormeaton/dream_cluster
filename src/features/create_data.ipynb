# %%
cd data/external/
# Out:
# /Users/cmeaton/Documents/code/ds/METIS/sea19_ds7_workingdir/project_4/data/external

# %%
import pandas as pd
import csv

df = pd.read_csv('Dreams_posts.csv')
df_2 = pd.read_csv('DreamInterpretation_posts.csv')
df_3 = pd.read_csv('DreamsCloud_posts.csv')
df_4 = pd.read_csv('Wierddreams_posts.csv')
df_5 = pd.read_csv('dreamreadings_posts.csv')
df_6 = pd.read_csv('Dream_posts.csv')
df_7 = pd.read_csv('Wierddreams_posts.csv')

frames = [df, df_2, df_3, df_4, df_5, df_6, df_7]

df_master = pd.concat(frames)

df_master.to_csv('final_dataframe.csv')

print(len(df_master))
df_master.head(10)
# Out:
# 4572
#    downs      id  num_comments  score  \
# 0    0.0  asb1hb           0.0    1.0
# 1    0.0  asazbm           0.0    1.0
# 2    0.0  asayws           0.0    1.0
# 3    0.0  asavcq           2.0    1.0
# 4    0.0  asaukg           0.0    1.0
# 5    0.0  ase97q           0.0    1.0
# 6    0.0  ase1dl           0.0    1.0
# 7    0.0  ascvzw           0.0    2.0
# 8    0.0  ascqwl           0.0    2.0
# 9    0.0  ascm4b           0.0    1.0
#
#                                             selftext sorted_by  \
# 0  Dream.\nStuck in a facility for people with me...       new
# 1  So I had a dream about a week ago where me and...       new
# 2  Hi. Most of my dreams are straight-up nightmar...       new
# 3  I’ve had some interesting very deep dreams las...       new
# 4  I don't remember everything, but I woke up fro...       new
# 5  Have you ever had a dream, in which not everyt...       new
# 6  all I can remember from my dream last night wa...       new
# ...
