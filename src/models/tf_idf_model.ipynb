# %%
import pickle
import pandas as pd
import csv
#tf-idf model and cosine similary querying
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel
import gensim.corpora as corpora
from gensim.models import TfidfModel


def train_tfidf_model(path):
    '''This function reads in the list of processed dreams and creates:
            - texts: a list of lists of words as strings
            - corpus: a bag-of-words list of lists of tuples
            - stringified_corpus: a bag-of-words of list of strings
            - tf_idf_model: a tf idf model trained on the corpus
            - The path I'm using for this project is "/Users/cmeaton/Documents/code/ds/METIS/sea19_ds7_workingdir/project_4/data/processed_data/processed_dreams.csv"'''
   
    with open(path, 'r') as f:
        reader = csv.reader(f)
        data_words_nostops = list(reader)
    
    # Create Dictionary
    id2word = corpora.Dictionary(data_words_nostops)
    # Create Corpus
    texts = data_words_nostops
    # Term Document Frequency
    corpus = [id2word.doc2bow(text) for text in texts]
    # convert corpus into string for fit_transform later
    stringified_corpus = [' '.join(i) for i in texts]
    # Build tf-idf model
    tf_idf_model = TfidfModel(corpus)
    
    # create tfidf vectorizer
    tfidf = TfidfVectorizer()
    # fit tfidf vectorizer on entire corpus
    queryTFIDF = tfidf.fit_transform(stringified_corpus)
    
    # pickle models, dict and corpus for later
    model_filename = "/Users/cmeaton/Documents/code/ds/METIS/sea19_ds7_workingdir/project_4/src/models/pickled_model_output/tfidf/tfid_vectorizer.sav"
    pickle.dump(queryTFIDF, open(model_filename, 'wb'))
    dic_filename = "/Users/cmeaton/Documents/code/ds/METIS/sea19_ds7_workingdir/project_4/src/models/pickled_model_output/tfidf/tfidf_model.sav"
    pickle.dump(tf_idf_model, open(dic_filename, 'wb'))
    corpus_filename = "/Users/cmeaton/Documents/code/ds/METIS/sea19_ds7_workingdir/project_4/src/models/pickled_model_output/tfidf/bow_corpus.sav"
    pickle.dump(stringified_corpus, open(corpus_filename, 'wb'))
    print(tf_idf_model)
    return texts, tf_idf_model, stringified_corpus
    
train_tfidf_model('/Users/cmeaton/Documents/code/ds/METIS/sea19_ds7_workingdir/project_4/data/processed_data/processed_dreams.csv'
)
# Out:
# TfidfModel(num_docs=4572, num_nnz=261826)
# ([['stuck',
#    'facility',
#    'people',
#    'mental',
#    'issue',
#    'meet',
#    'girl',
#    'starnge',
#    'thing',
#    'begin',
#    'happen',
#    'meet',
#    'form',
#    'group',
#    'find',
#    'fall',
#    'love',
#    'girl',
#    'like',
#    'show',
#    'maybe',
#    'like',
#    'stick',
#    'together',
#    'leave',
#    'reject',
#    'demon',
#    'monster',
#    'shape',
#    'shift',
#    'black',
#    'dog',
#    'sacrifice',
#    'people',
#    'nowhere',
#    'capture',
#    'demon',
#    'girl',
#    'away',
#    'release',
#    'stumble',
#    'city',
#    'fight',
#    'sure',
#    'girl',
#    'dad',
#    'find',
#    'bring',
#    'sit',
#    'strange',
#    'room',
#    'big',
#    'warehouse',
#    'discuss',
#    'happen',
#    'feeling',
#    'stay',
#    'attempt',
#    'leave',
#    'learn',
#    'somehow',
#    'florence',
#    'italy',
#    'far',
#    'american',
#    'home',
#    'return',
#    'facility',
#    'find',
#    'girl',
#    'dad',
#    'figure',
#    'everyone',
#    'leave',
#    'dad',
#    'longer',
#    'work',
#    'leave',
#    'doctor',
#    'assistant',
#    'girl',
#    'apparently',
#    'hold',
#    'captive',
#    'organization',
#    'experiment',
#    'thing',
#    'begin',
#    'weird',
#    'tell',
#    'anything',
#    'car',
#    'people',
#    'girl',
#    'amanda',
#    'bander',
#    'walk',
#    'doctor',
#    'tell',
#    'able',
#    'leave',
#    'explain',
#    'whyi',
#    'wake'],
#   ['week',
#    'ago',
#    'close',
#    'friend',
#    'sex',
#    'bit',
#    'context',
#    'friend',
#    'attractive',
#    'never',
#    'pursue',
#    'anything',
#    'hook',
#    'relationship',
#    'real',
#    'life',
#    'little',
#    'sister',
#    'boyfriend',
#    'mate',
#    'bed',
#    'room',
#    'people',
#    'intercourse',
#    'actually',
#    'bang',
#    'force',
#    'field',
#    'around',
#    'happen',
#    'ready',
#    'dirty',
#    'invisible',
#    'force',
#    'stop',
#    'fornicate',
#    'happen',
#    'someone',
#    'room',
#    'wake',
#    'tell',
#    'friend',
#    'quiet',
#    'scream',
#    'care',
#    'date',
#    'top',
#    'lung',
#    'travel',
#    'part',
#    'seemingly',
#    'unrelated',
#    'situation',
#    'woke',
#    'fuck',
#    'happen',
#    'week',
#    'later',
#    'still',
#    'thing',
#    'wonder',
#    'someone',
#    'help',
#    'figure',
#    'mean',
#    'anything',
#    'add',
#    'fact',
#    'kind',
#    'answer',
#    'question',
#    'never',
#    'pursue',
#    'way',
#    'real',
#    'life',
#    'much',
#    'appreciate'],
#   ['straightup',
#    'nightmare',
#    'insomnia',
#    'sheer',
#    'terror',
#    'one',
#    'beauty',
#    'insight',
#    'appreciate',
#    'invite',
#    'dinner',
#    'depart',
#    'grandfather',
#    'house',
#    'arrive',
#    'family',
#    'dead',
#    'seat',
#    'become',
#    'host',
#    'guest',
#    'nosferatu',
#    'friend',
#    'find',
#    'food',
#    'drink',
#    'promise',
#    'house',
#    'everything',
#    'find',
#    'rotten',
#    'guest',
#    'nosferatu',
#    'bring',
#    'goat',
#    'head',
#    'serve',
#    'raw',
#    'hair',
#    'everyone',
#    'different',
#    'specific',
#    'drink',
#    'provide',
#    'overtone',
#    'menace',
#    'animal',
#    'fresco',
#    'wall',
#    'ceiling',
#    'life',
#    'threaten',
#    'fail',
#    'guest',
#    'nosferatu',
#    'crawl',
#    'leg',
#    'table',
#    'chant',
#    'language',
#    'understand',
#    'wake',
#    'drenched_sweat',
#    'fuck'],
#   ['interesting',
#    'deep',
#    'last_night',
#    'kinda',
#    'mix',
#    'together',
#    'remember',
#    'quite',
#    'well',
#    'first',
#    'actually',
#    'different',
#    'single',
#    'include',
#    'bus',
#    'somehow',
#    'pick',
#    'bus',
#    'wrong',
#    'side',
#    'funny',
#    'mistake',
#    'occasionally',
#    'real',
#    'life',
#    'remember',
#    'bus',
#    'local',
#    'shop',
#    'bus',
#    'stop',
#    'irl',
#    'realize',
#    'wrong',
#    'side',
#    'idk',
#    'careless',
#    'tired',
#    'feeling',
#    'fuck',
#    'well',
#    'wrong',
#    'side',
#    'wait',
#    'turn',
#    'one',
#    'sure',
#    'big',
#    'bus',
#    'wrong',
#    'side',
#    'already',
#    'half',
#    'route',
#    'ill',
#    'wait',
#    'turn',
#    'end',
#    'tho',
#    'irl',
#    'sense',
#    'time',
#    'efficient',
#    'scene',
#    'remember',
#    'leo',
#    'classmate',
#    'well',
#    'light',
#    'red',
#    'building',
#    'familiar',
#    'bit',
#    'irl',
#    'actually',
#    'church',
#    'really',
#    'interesting',
#    'recur',
#    'location',
#    'world',
#    'anyway',
#    'past',
#    'university',
#    'campus',
#    'student',
#    'find',
#    'bus',
#    'station',
#    'destination',
#    'something',
#    'ask',
#    'student',
#    'wall',
#    'idea',
#    'wall',
#    'epic',
#    'one',
#    'bus',
#    'night',
#    'random',
#    'location',
#    'red',
#    'building',
#    'wall',
#    'home',
#    'direction',
#    'point',
#    'become',
#    'sort',
#    'halflucid',
#    'concentrate',
#    'hard',
#    'home',
#    'though',
#    'prolly',
#    'house',
#    'view',
#    'sort',
#    'rip',
#    'half',
#    'few_second',
#    'neighborhood',
#    'eventually',
#    'inside',
#    'apartment',
#    'building',
#    'divine',
#    'light',
#    'shin',
#    'way',
#    'apartment',
#    'somehow',
#    'open',
#    'door',
#    'apartment',
#    'clone',
#    'surround',
#    'divine',
#    'light',
#    'head',
#    'saint',
#    'religious',
#    'icon',
#    'body',
#    'tell',
#    'love',
#    'wake',
#    'ton',
#    'shit',
#    'remember',
#    'weird',
#    'feel',
#    'important',
#    'vivid',
#    'emotional',
#    'forgettable',
#    'actually',
#    'content',
#    'deep',
#    'shit',
#    'analysis',
#    'thing',
#    'paragraph',
#    'probably',
#    'mean',
#    'something',
#    'irl',
#    'wrong',
#    'way',
#    'consider',
#    'halffinished',
#    'well',
#    'finish',
#    'process',
#    'wall',
#    'paragraph',
#    'probably',
#    'mean',
#    'obstacle',
#    'ill',
#    'destination',
#    'dreambiblecom',
#    'entry',
#    'church',
#    'legit',
#    'church',
#    'represent',
#    'answer',
#    'life',
#    'problem',
#    'bother',
#    'insight',
#    'solution',
#    'kind',
#    'guidance',
#    'direction',
#    'something',
#    'happen',
#    'reach',
#    'crossroad',
#    'ask',
#    'suppose',
#    'situation',
#    'suppose',
#    'life'],
#   ['remember',
#    'everything',
#    'wake',
#    'control',
#    'body',
#    'action',
#    'thing',
#    'scream',
#    'people',
#    'peel',
#    'skin',
#    'violent',
#    'behavior',
#    'definitely',
#    'pleasant',
#    'control',
#    'curious',
#    'reason',
#    'meaning'],
#   ['ever', 'everything', 'focus', 'someone', 'else', 'instead'],
#   ['remember',
#    'last_night',
#    'shoe',
#    'store',
#    'pair',
#    'reebok',
#    'buck',
#    'reebok',
#    'buck',
#    'mean',
#    'something',
#    'suppose',
#    'mean'],
#   ['first',
#    'night',
#    'watch',
#    'really',
#    'fuck',
#    'animation',
#    'immigrant',
#    'child',
#    'name',
#    'jacquee',
#    'female',
#    'killl',
#    'animation',
#    'awake',
#    'stand',
#    'bedroom',
#    'lean',
#    'fat',
#    'black',
#    'man',
#    'room',
#    'wear',
#    'tuck',
#    'black',
#    'polo',
#    'blue_jean',
#    'metal',
#    'security',
#    'badge',
#    'belt',
#    'never',
#    'guy',
#    'room',
#    'ask',
#    'jacquee',
#    'view',
#    'shin',
#    'tiny',
#    'light',
#    'small',
#    'circular',
#    'flash',
#    'face',
#    'wake',
#    'weird',
#    'feel',
#    'scared',
#    'enough',
#    'wake',
#    'panic',
#    'scared',
#    'didjust',
#    'confuse',
#    'almost',
#    'something',
#    'else',
#    'sleep',
#    'happen',
#    'time',
#    'still',
#    'bed',
#    'bright',
#    'outside',
#    'bedside',
#    'female',
#    'version',
#    'black',
#    'man',
#    'visit',
#    'last',
#    'name',
#    'katherine',
#    'devil',
#    'remember',
#    'specialist',
#    'group',
#    'light',
#    'blue',
#    'woke',
#    'oddly',
#    'feel',
#    'scared',
#    'worried',
#    'wake',
#    'something',
#    'someone',
#    'anyway',
#    'wake',
#    'intense',
#    'nose',
#    'bleed',
#    'pain',
#    'blood',
#    'nose',
#    'bleed',
#    'nose',
#    'bleed',
#    'month',
#    'mean',
#    'exactly',
#    'share'],
#   ['sudently',
#    'hospital',
#    'hall',
#    'woman',
#    'directly',
#    'crowded',
#    'room',
#    'tall',
#    'thin',
#    'big',
#    'eye',
#    'lip',
#    'short',
#    'brown_hair',
#    'dirty',
#    'old',
#    'clothe',
#    'weird',
#    'appereance',
#    'people',
#    'notice',
#    'feel',
#    'scared',
#    'away',
#    'chase',
#    'sudently',
#    'mom',
#    'hospital',
#    'room',
#    'sit',
#    'wake',
#    'reciev',
#    'text',
#    'message',
#    'weird',
#    'woman',
#    'paragraph',
#    'write',
#    'scar',
#    'multiple_time',
#    'always',
#    'wake',
#    'panicking',
#    'anyone',
#    'mean'],
#   ['food', 'angry'],
#   ['maybe',
#    'deal',
#    'explanation',
#    'feel',
#    'pleasure',
#    'love',
#    'express',
#    'much',
#    'tune',
#    'full',
#    'potential',
#    'capability',
#    'human',
#    'sens',
#    'work',
#    'great',
#    'reality',
#    'everything',
#    'pretty',
#    'dull',
#    'lackluster',
#    'feel',
#    'much',
#    'physical',
#    'emotional',
#    'pleasure',
#    'sexual',
#    'romantic',
#    'enthusiasm',
#    'twist',
#    'way',
#    'around',
#    'sure',
#    'feel',
#    'pleasure',
#    'real',
#    'life',
#    'everything',
#    'vivid',
#    'normal',
#    'something',
#    'brain',
#    'change',
#    'medication',
#    'feel',
#    'depressed',
#    'depersonalize',
#    'anything',
#    'content',
#    'life',
#    'place',
#    'acceptance',
#    'thing',
#    'live',
#    'life',
#    'regret',
#    'feel',
#    'truly',
#    'bless',
#    'life',
#    'fairly',
#    'stable',
#    'bad',
#    'pm',
#    'month',
#    'stable',
#    'relationship',
#    'sweet',
#    'caring',
#    'man',
#    'frustrating',
#    'wake',
#    'monotony',
#    'able',
#    'feel',
#    'thing',
#    'everything',
#    'excitement',
#    'genuine',
#    'laughter',
#    'happiness',
#    'real',
#    'bad',
#    'sexual',
#    'feeling',
#    'sensation',
#    'feel',
#    'definitely',
#    'screw',
#    'relationship',
#    'orgasm',
#    'real',
#    'life',
#    'basically',
#    'numb',
#    'day',
#    'dichotomy',
#    'due',
#    'medically',
#    'tell',
#    'fine',
#    'clue',
#    'deal',
#    'anyway',
#    'chest',
#    'super',
#    'annoying',
#    'happen',
#    'year',
#    'feel',
#    'live',
#    'double',
#    'life',
#    'least',
#    'feel',
#    'something',
#    'sure',
#    'truly',
#    'nsfw',
#    'better',
#    'safe',
#    'sorry'],
#   ['last_night',
#    'play',
#    'kind',
#    'casino',
#    'game',
#    'win',
#    'excited',
#    'machine',
#    'spit',
#    'small',
#    'bill',
#    'cash',
#    'rest',
#    'hashbrown',
#    'loose',
#    'oily',
#    'undercooked',
#    'hashbrown',
#    'hashbrown',
#    'find',
#    'slip',
#    'cover',
#    'cook',
#    'oil',
#    'redeem',
#    'point',
#    'stop',
#    'redeem',
#    'slip',
#    'pretty',
#    'happy',
#    'hashbrown',
#    'deal',
#    'scrape',
#    'slot',
#    'machine',
#    'lol'],
#   ['past',
#    'week',
#    'cheat',
#    'boyfriend',
#    'mean',
#    'feel',
#    'kind',
#    'low',
#    'relationship',
#    'due'],
#   ['hear', 'true', 'anything', 'time', 'help'],
#   ['grandma',
#    'house',
#    'stop',
#    'live',
#    'wheelchair',
#    'ramp',
#    'stair',
#    'door',
#    'foot',
#    'side',
#    'door',
#    'basement',
#    'grandma',
#    'disappointment',
#    'water',
#    'bead',
#    'ceiling',
#    'water',
#    'fill',
#    'glass',
#    'lamp',
#    'shade',
#    'ceiling',
#    'fixture',
#    'inch',
#    'water',
#    'grandma',
#    'keep',
#    'goldfish',
#    'laugh',
#    'reply',
#    'upstairs',
#    'family_member',
#    'pack',
#    'house',
#    'house',
#    'always',
#    'clean',
#    'austere',
#    'type',
#    'place',
#    'bookend',
#    'plastic',
#    'fruit',
#    'coffee_table',
#    'around',
#    'severe',
#    'locked',
#    'door',
#    'dark',
#    'staircase',
#    'much',
#    'original',
#    'house',
#    'real',
#    'life',
#    'bit',
#    'creepy',
#    'feeling',
#    'paint',
#    'kind',
#    'green',
#    'frankenstein',
#    'monsterskin',
#    'find',
#    'different',
#    'door',
#    'door',
#    'blanket',
#    'tack',
#    'doorframe',
#    'find',
#    'attic',
#    'room',
#    'book',
#    'poster',
#    'diary',
#    'table',
#    'pop',
#    'open',
#    'whose',
#    'read',
#    'sister',
#    'name',
#    'call',
#    'suddenly',
#    'arrive',
#    'pleased',
#    'diary',
#    'open',
#    'read',
#    'aloud',
#    'write',
#    'learn',
#    'aerodynamic',
#    'thermal',
#    'draft',
#    'sister',
#    'child',
#    'interest',
#    'science',
#    'find',
#    'beautifully',
#    'colorful',
#    'sheet',
#    'music',
#    'type',
#    'color',
#    'font',
#    'graphic',
#    'exist',
#    'realize',
#    'sheet',
#    'music',
#    'disney',
#    'movie',
#    'full',
#    'sized',
#    'poster',
#    'glyni',
#    'dress',
#    'suffragette',
#    'mother',
#    'mary',
#    'poppin',
#    'begin',
#    'sister',
#    'great',
#    'collection',
#    'auction',
#    'money',
#    'woke',
#    'wonder',
#    'anyone',
#    'idea',
#    'mean'],
#   ['last_night',
#    'johnny',
#    'cash',
#    'potentially',
#    'alternate',
#    'universe',
#    'family',
#    'weird',
#    'johnny',
#    'least',
#    'live',
#    'suburban',
#    'area',
#    'sun',
#    'set',
#    'yellow',
#    'orange',
#    'everywhere',
#    'setting',
#    'never',
#    'away',
#    'set',
#    'way',
#    'forever',
#    'walk',
#    'knock',
#    'door',
#    'answer',
#    'must',
#    'buyer',
#    'meet',
#    'johnny',
#    'purchase',
#    'black',
#    'vehicle',
#    'dodge',
#    'monaco',
#    'sedan',
#    'solid',
#    'black',
#    'blue',
#    'bro',
#    'anyway',
#    'give',
#    'black',
#    'cat',
#    'key',
#    'dodge',
#    'talk',
#    'minute',
#    'remember',
#    'goodbye',
#    'car',
#    'daughter',
#    'forget',
#    'laptop',
#    'car',
#    'daddy',
#    'read',
#    'unfinished',
#    'book',
#    'return',
#    'laptop',
#    'instantly',
#    'blink',
#    'eye',
#    'couch',
#    'type',
#    'away',
#    'leave',
#    'johnnys',
#    'house',
#    'drive',
#    'vehicle',
#    'sun',
#    'never',
#    'set',
#    'time',
#    'buy',
#    'talk',
#    'johnny',
#    'thing',
#    'sudden',
#    'street',
#    'buy',
#    'car',
#    'house',
#    'escape',
#    'third',
#    'floor',
#    'basement',
#    'hide',
#    'people',
#    'flood',
#    'house',
#    'speak',
#    'note',
#    'entire',
#    'johnny',
#    'cashs',
#    'song',
#    'played',
#    'background',
#    'music'],
#   ['evening',
#    'overindulge',
#    'unhealthy',
#    'food',
#    'sleep',
#    'feel',
#    'discomforted',
#    'low',
#    'lie',
#    'put',
#    'hand',
#    'abdominal',
#    'area',
#    'notice',
#    'something',
#    'strange',
#    'feeling',
#    'area',
#    'feeling',
#    'dark',
#    'feeling',
#    'travel',
#    'body',
#    'stop',
#    'hearth',
#    'begin',
#    'fight',
#    'demon',
#    'emotional',
#    'battle',
#    'couragous',
#    'attacke',
#    'synchronicity',
#    'hearth',
#    'beat',
#    'reading',
#    'let'],
#   ['recently',
#    'stab',
#    'needle',
#    'syringe',
#    'contain',
#    'heroin',
#    'open',
#    'drank',
#    'inject',
#    'reason',
#    'needle',
#    'stuck',
#    'skin',
#    'slowly',
#    'pull',
#    'last_night',
#    'walk',
#    'grass',
#    'barefoot',
#    'blade',
#    'grass',
#    'lodge',
#    'foot',
#    'pull',
#    'mean',
#    'anything'],
#   [],
#   ['last_night',
#    'swim',
#    'cliff',
#    'water',
#    'endless',
#    'deep',
#    'choppy',
#    'clear',
#    'water',
#    'creature',
#    'far',
#    'hostile',
#    'aware',
#    'presence',
#    'watch',
#    'struggle',
#    'whole',
#    'time',
#    'sense',
#    'unease',
#    'fear',
#    'reach',
#    'side',
#    'climb',
#    'high',
#    'cliff',
#    'plunge',
#    'give',
#    'new',
#    'sense',
#    'unease',
#    'time',
#    'woke',
#    'remember',
#    'everything'],
#   ['detail',
#    'one',
#    'hazy',
#    'pretty',
#    'short',
#    'live',
#    'future',
#    'contact',
#    'alien',
#    'specifically',
#    'ask',
#    'visit',
#    'spacecraft',
#    'direction',
#    'arrive',
#    'destination',
#    'realize',
#    'stereotypical',
#    'alien',
#    'alien',
#    'extension',
#    'spirit',
#    'universe',
#    'invisible',
#    'solely',
#    'love',
#    'ask',
#    'join',
#    'sit',
#    'spacecraft',
#    'star',
#    'wall',
#    'star',
#    'planet',
#    'front',
#    'become',
#    'anxious',
#    'tear',
#    'join',
#    'afraid',
#    'next',
#    'thing',
#    'home',
#    'watch',
#    'mom'],
#   ['term',
#    'parent',
#    'wake',
#    'middle',
#    'hate',
#    'day',
#    'anger',
#    'feel',
#    'strong',
#    'sometimes',
#    'remain',
#    'pissed',
#    'entire',
#    'day',
#    'parent',
#    'always',
#    'horrible',
#    'people',
#    'way',
#    'hate',
#    'parent',
#    'irl',
#    'hate'],
#   ['wake',
#    'slide',
#    'cover',
#    'drop',
#    'foot',
#    'floor',
#    'stumble',
#    'fall',
#    'wake',
#    'lift',
#    'cover',
#    'cautiously',
#    'low',
#    'floor',
#    'door',
#    'stomach',
#    'spin',
#    'puke',
#    'everything',
#    'fades_black',
#    'wake',
#    'determine',
#    'rip',
#    'cover',
#    'jump',
#    'floor',
#    'room',
#    'spin',
#    'stumble',
#    'door',
#    'door',
#    'girl',
#    'sit',
#    'base',
#    'call',
#    'unseen',
#    'force',
#    'upward',
#    'shirt',
#    'ascend',
#    'room',
#    'fade',
#    'away',
#    'replace',
#    'brilliant',
#    'swirling',
#    'pattern',
#    'perfect',
#    'golden',
#    'fractal',
#    'order',
#    'place',
#    'yet',
#    'end',
#    'detail',
#    'everything',
#    'motion',
#    'sync',
#    'weightless',
#    'nausea',
#    'banish',
#    'mind',
#    'fill',
#    'wonder',
#    'something',
#    'large',
#    'something',
#    'yet',
#    'understand',
#    'wall',
#    'wake'],
#   ['last_night',
#    'someone',
#    'sex',
#    'really',
#    'decline',
#    'always',
#    'turn',
#    'sex'],
#   ['hunt',
#    'ring',
#    'wear',
#    'silver',
#    'ring',
#    'forest',
#    'guy',
#    'keep',
#    'hunt',
#    'close',
#    'never',
#    'able',
#    'catch',
#    'army',
#    'everywhere',
#    'bad',
#    'guy',
#    'keep',
#    'end',
#    'ambushed',
#    'everyone',
#    'follow',
#    'man',
#    'constantly',
#    'chase',
#    'massive',
#    'fight',
#    'end',
#    'win',
#    'fire',
#    'surround',
#    'bit',
#    'put',
#    'ring',
#    'time',
#    'fly',
#    'year',
#    'year',
#    'place',
#    'massive',
#    'fight',
#    'people',
#    'still',
#    'disguise',
#    'really',
#    'weird',
#    'anyone',
#    'thought',
#    'mean'],
#   [],
#   ['reason',
#    'wife',
#    'invite',
#    'mil',
#    'yianapolous',
#    'probably',
#    'spell',
#    'wrong',
#    'house',
#    'really',
#    'upset',
#    'like',
#    'person',
#    'hang',
#    'choice',
#    'wake',
#    'sure',
#    'enough',
#    'listen',
#    'podcast',
#    'talk',
#    'milo',
#    'weird'],
#   [],
#   ['type',
#    'actually',
#    'never',
#    'theme',
#    'highly',
#    'attracted',
#    'woman',
#    'exist',
#    'real',
#    'life',
#    'hook',
#    'suddenly',
#    'remember',
#    'boyfriend',
#    'panic',
#    'mean',
#    'really',
#    'panic',
#    'cheat',
#    'tell',
#    'deserf',
#    'omg',
#    'tell',
#    'eye',
#    'devastated',
#    'relationship',
#    'fault',
#    'way',
#    'fix',
#    'etc',
#    'sometimes',
#    'panic',
#    'realize',
#    'really',
#    'cheat',
#    'calm',
#    'still',
#    'feel',
#    'disgusted',
#    'wake',
#    'technique',
#    'help',
#    'away'],
#   ['spend',
#    'past',
#    'week',
#    'hotel',
#    'friend',
#    'family',
#    'canada',
#    'explore',
#    'building',
#    'hotel',
#    'stay',
#    'discover',
#    'room',
#    'swear',
#    'really',
#    'sure',
#    'explain',
#    'swear',
#    'auditorium',
#    'image',
#    'mind',
#    'conjure',
#    'bore',
#    'burden',
#    'conscious',
#    'train',
#    'thought',
#    'soon',
#    'walk',
#    'door',
#    'manage',
#    'recall',
#    'correctly',
#    'auditorium',
#    'fill',
#    'people',
#    'sit',
#    'table',
#    'love',
#    'one',
#    'present',
#    'life',
#    'way',
#    'stand',
#    'door',
#    'way',
#    'wave',
#    'doorway',
#    'place',
#    'auditorium',
#    'find',
#    'difference',
#    'auditorium',
#    'empty',
#    'table',
#    'explain',
#    'friend',
#    'makes_sense',
#    'mind',
#    'curious',
#    'research',
#    'possibly',
#    'find',
#    'rough',
#    'guess',
#    'phenomenon',
#    'experienced',
#    'figure',
#    'input',
#    'community',
#    'interested',
#    'type',
#    'thing',
#    'read'],
#   ['past',
#    'night',
#    'family',
#    'reunion',
#    'cousin',
#    'uncle',
#    'grandfather',
#    'pin',
#    'tickle',
#    'exclusively',
#    'move',
#    'fight',
#    'escape',
#    'slight',
#    'smirk',
#    'face',
#    'tickle',
#    'fetish',
#    'cousin',
#    'uncle',
#    'grandpa',
#    'really',
#    'disturbed',
#    'mixed',
#    'fetish',
#    'thought',
#    'family',
#    'jerk',
#    'turn'],
#   ['park', 'several', 'people', 'different', 'person', 'school', 'school'],
#   ['artsyfartsy',
#    'restaurant',
#    'turn',
#    'spa',
#    'man',
#    'ask',
#    'leg',
#    'shave',
#    'station',
#    'pause',
#    'different',
#    'man',
#    'pornstache',
#    'weird',
#    'razor',
#    'leg',
#    'barely',
#    'shave',
#    'strip',
#    'leg',
#    'totally',
#    'bypass',
#    'first',
#    'guy',
#    'chair',
#    'motorize',
#    'conveyor',
#    'belt',
#    'man',
#    'exfoliate',
#    'leg',
#    'ankle',
#    'specifically',
#    'really',
#    'goo',
#    'scoop',
#    'handful',
#    'home',
#    'put',
#    'goopy',
#    'hand',
#    'wait',
#    'belt',
#    'turn',
#    'something',
#    'slip',
#    'slide',
#    'safe',
#    'sit',
#    'tube',
#    'float',
#    'river',
#    'foot',
#    'dangle',
#    'whirlpool',
#    'somehow',
#    'naked',
#    'find',
#    'clothe',
#    'ride',
#    'home',
#    'money',
#    'lady',
#    'gift',
#    'shop',
#    'let',
#    'put',
#    'crazy',
#    'yoga',
#    'clothe',
#    'tab',
#    'boss',
#    'work',
#    'purse',
#    'upset',
#    'usually',
#    'act',
#    'upset',
#    'work',
#    'unruly',
#    'child',
#    'show',
#    'upset',
#    'wait',
#    'long',
#    'apparently',
#    'weird',
#    'yoga',
#    'clothe',
#    'holy',
#    'rip',
#    'fray',
#    'footed',
#    'legging',
#    'remember',
#    'top',
#    'search',
#    'car',
#    'finally',
#    'home',
#    'destroy',
#    'search',
#    'husband',
#    'find',
#    'teenager',
#    'play',
#    'video_game',
#    'handheld',
#    'device'],
#   ['keep',
#    'year',
#    'brain',
#    'communicate',
#    'feel',
#    'search',
#    'entire',
#    'freak',
#    'mind',
#    'weird',
#    'trouble',
#    'sense',
#    'anyway',
#    'ignore',
#    'keep',
#    'anyone',
#    'help',
#    'sister',
#    'whatev',
#    'brain',
#    'tell',
#    'sometimes',
#    'interconnect',
#    'ill',
#    'give',
#    'background',
#    'mean',
#    'kind',
#    'mean',
#    'end',
#    'description',
#    'anything',
#    'super',
#    'specific',
#    'hard',
#    'yall',
#    'time',
#    'ear',
#    'really',
#    'direction',
#    'overall',
#    'theme',
#    'mean',
#    'connected',
#    'idea',
#    'mind',
#    'tell',
#    'female',
#    'suffering',
#    'mental_illness',
#    'jack',
#    'life',
#    'functional',
#    'neurological',
#    'disorder',
#    'art',
#    'school',
#    'illness',
#    'mess',
#    'arm',
#    'draw',
#    'anymore',
#    'drop',
#    'await',
#    'treatment',
#    'traumatic',
#    'abusive',
#    'childhood',
#    'disorder',
#    'stem',
#    'logical',
#    'factual',
#    'type',
#    'person',
#    'intuitive',
#    'creative',
#    'objective',
#    'intj',
#    'mbti',
#    'strong',
#    'believer',
#    'christ',
#    'info',
#    'let',
#    'live',
#    'bedroom',
#    'scrapheap',
#    'year',
#    'life',
#    'people',
#    'recently',
#    'move',
#    'apartment',
#    'idk',
#    'maybe',
#    'help',
#    'anyone',
#    'help',
#    'little',
#    'temporarily',
#    'place',
#    'fixer',
#    'upper',
#    'home',
#    'wait',
#    'new',
#    'apartment',
#    'ready',
#    'move',
#    'something',
#    'bad',
#    'always',
#    'happen',
#    'big',
#    'mansion',
#    'kind',
#    'jack',
#    'place',
#    'multiple',
#    'rendition',
#    'people',
#    'break',
#    'window',
#    'attack',
#    'one',
#    'neighbor',
#    'bear',
#    'lion',
#    'break',
#    'home',
#    'chase',
#    'nothing',
#    'ever',
#    'house',
#    'big',
#    'spacious',
#    'always',
#    'ask',
#    'mom',
#    'new',
#    'apartment',
#    'wait',
#    'repeat',
#    'different',
#    'situation',
#    'always',
#    'kind',
#    'house',
#    'something',
#    'bad',
#    'always',
#    'happen',
#    'thought',
#    'fear',
#    'move',
#    'something',
#    'move',
#    'still',
#    'stay',
#    'mom',
#    'old',
#    'friend',
#    'house',
#    'live',
#    'irl',
#    'stay',
#    'find',
#    'new',
#    'apartment',
#    'food',
#    'exb',
#    'friend',
#    'mom',
#    'live',
#    'sometimes',
#    'house',
#    'multiple',
#    'room',
#    'different',
#    'random',
#    'people',
#    'sleep',
#    'party',
#    'different',
#    'rendition',
#    'friend',
#    'different',
#    'point',
#    'different',
#    'crazy',
#    'rude',
#    'real',
#    'life',
#    'something',
#    'terrible',
#    'break',
#    'remind',
#    'mean',
#    'remorseful',
#    'angry',
#    'dramatic',
#    'fight',
#    'wake',
#    'part',
#    'stay',
#    'house',
#    'thursday',
#    'gang',
#    'shootout',
#    'sport',
#    'cannibal',
#    'shoot',
#    'neighborhood',
#    'house',
#    'game',
#    'feast',
#    'eat',
#    'people',
#    'kill',
#    'always',
#    'hide',
#    'something',
#    'lay',
#    'real',
#    'flat',
#    'people',
#    'home',
#    'shoot',
#    'scary',
#    'different',
#    'rendition',
#    'grandma',
#    'mom',
#    'brother',
#    'protect',
#    'warn',
#    'happen',
#    'real',
#    'life',
#    'move',
#    'new',
#    'apartment',
#    'shift',
#    'situation',
#    'mom',
#    'brother',
#    'always',
#    'beg',
#    'home',
#    'new',
#    'place',
#    'ask',
#    'stay',
#    'somewhere',
#    'live',
#    'leave',
#    'sometimes',
#    'new',
#    'home',
#    'sometimes',
#    'deal',
#    'gang',
#    'mix',
#    'match',
#    'different',
#    'day',
#    'theme',
#    'situation',
#    'always',
#    'revolve',
#    'thing',
#    'confuse',
#    'friend',
#    'break',
#    'bad',
#    'feeling',
#    'friend',
#    'accept',
#    'thatdoe',
#    'mean',
#    'reconnect',
#    'closure',
#    'something',
#    'irl',
#    'remorseful',
#    'somehow',
#    'keep',
#    'show',
#    'far',
#    'house',
#    'gang',
#    'thing',
#    'nooo',
#    'idea',
#    'move',
#    'new',
#    'home',
#    'love',
#    'one',
#    'cheap',
#    'move',
#    'weird',
#    'ever',
#    'change',
#    'house',
#    'always',
#    'rabbit',
#    'always',
#    'escape',
#    'cheap',
#    'home',
#    'bad',
#    'area',
#    'first',
#    'house',
#    'real',
#    'life',
#    'weird',
#    'crazy',
#    'people',
#    'drug',
#    'addict',
#    'around',
#    'street',
#    'liquor',
#    'store',
#    'someone',
#    'always',
#    'shoot',
#    'something',
#    'dangerous',
#    'happen',
#    'end',
#    'old',
#    'house',
#    'old',
#    'man',
#    'talk',
#    'way',
#    'old',
#    'house',
#    'give',
#    'trinket',
#    'rise',
#    'different',
#    'way',
#    'sometimes',
#    'first',
#    'part',
#    'part',
#    'sometimes',
#    'fuse',
#    'rabbit',
#    'escape',
#    'evoke',
#    'feeling',
#    'scared',
#    'anxious',
#    'deprive',
#    'move',
#    'weird',
#    'cheap',
#    'house',
#    'weird',
#    'change',
#    'upsidedown',
#    'infrastructure',
#    'old',
#    'high_school',
#    'somehow',
#    'day',
#    'massive',
#    'flood',
#    'high',
#    'high',
#    'student',
#    'end',
#    'trap',
#    'tall',
#    'building',
#    'seclude',
#    'cave',
#    'jump',
#    'cliff',
#    'land',
#    'directly',
#    'rescue',
#    'boat',
#    'save',
#    'sometimes',
#    'rendition',
#    'boat',
#    'show',
#    'wake',
#    'flood',
#    'drown',
#    'little',
#    'thought',
#    'keep',
#    'switch',
#    'past',
#    'year',
#    'year',
#    'anything',
#    'long',
#    'helpful',
#    'help',
#    'point',
#    'resource',
#    'hellp',
#    'plzzz'],
#   ['essentially',
#    'revolve',
#    'speed',
#    'end',
#    'kind',
#    'ancient',
#    'aztec',
#    'tunnel',
#    'tunnel',
#    'surround',
#    'black',
#    'void',
#    'loop',
#    'sideway',
#    'shape',
#    'end',
#    'float',
#    'brown',
#    'tablet',
#    'appear',
#    'begin',
#    'display',
#    'text',
#    'autonomous',
#    'command',
#    'prompt',
#    'specific',
#    'multicolour',
#    'cartoon',
#    'infant',
#    'creature',
#    'wear',
#    'face',
#    'display',
#    'infront',
#    'float',
#    'tablet',
#    'contemplate',
#    'change',
#    'text',
#    'purpose',
#    'waswhat',
#    'moment',
#    'tablet',
#    'decide',
#    'simply',
#    'erase',
#    'infant',
#    'moment',
#    'creature',
#    'dissipate',
#    'thin',
#    'air',
#    'tablet',
#    'read',
#    'aforementioned',
#    'sentence',
#    'cia',
#    'puro',
#    'purgo',
#    'houka',
#    'lid',
#    'body',
#    'time',
#    'wonder',
#    'tablet',
#    'speak',
#    'french',
#    'wake',
#    'anything',
#    'else',
#    'happen',
#    'course',
#    'leave',
#    'wonder',
#    'sentence',
#    'mean',
#    'connection',
#    'purge',
#    'multicolour',
#    'juvenile'],
#   ['dad',
#    'beauty',
#    'contest',
#    'enter',
#    'drive',
#    'first',
#    'pass',
#    'huge',
#    'cemetery',
#    'statue',
#    'abstract',
#    'face',
#    'explain',
#    'dad',
#    'statue',
#    'way',
#    'house',
#    'spirit',
#    'haunt',
#    'something',
#    'ghost',
#    'possess',
#    'arrive',
#    'building',
#    'contest',
#    'hold',
#    'host',
#    'greet',
#    'state',
#    'building',
#    'super',
#    'haunt',
#    'worry',
#    'lead',
#    'hallway',
#    'dressing',
#    'area',
#    'supply',
#    'makeup',
#    'sort',
#    'explain',
#    'ill',
#    'next',
#    'shortly',
#    'quickly',
#    'put',
#    'makeup',
#    'pink',
#    'glitter',
#    'thought',
#    'throw',
#    'pink',
#    'white',
#    'gown',
#    'proceed',
#    'entrance',
#    'stage',
#    'host',
#    'stage',
#    'lady',
#    'gentleman',
#    'let',
#    'introduce',
#    'new',
#    'contestant',
#    'trisha',
#    'sowash',
#    'walk',
#    'stage',
#    'crowd',
#    'quiet',
#    'hear',
#    'footstep',
#    'continue',
#    'walkway',
#    'phase',
#    'silence',
#    'stop',
#    'end',
#    'walkway',
#    'stare',
#    'crowd',
#    'deafening',
#    'silence',
#    'ring',
#    'ear',
#    'turn',
#    'exit',
#    'stage',
#    'leave',
#    'woman',
#    'walk',
#    'walkway',
#    'hear',
#    'half',
#    'crowd',
#    'cheer',
#    'thought',
#    'tough',
#    'crowd',
#    'enter',
#    'lobby',
#    'building',
#    'pack',
#    'people',
#    'examine',
#    'beauty',
#    'dress',
#    'man',
#    'talk',
#    'way',
#    'away',
#    'keep',
#    'job',
#    'coach',
#    'trisha',
#    'new',
#    'one',
#    'pretty',
#    'much',
#    'option',
#    'man',
#    'sit',
#    'respond',
#    'nobody',
#    'cheer',
#    'accept',
#    'someone',
#    'nobody',
#    'like',
#    'turn',
#    'away',
#    'sadden',
#    'truth',
#    'nobody',
#    'like',
#    'performance',
#    'little',
#    'wander',
#    'lobby',
#    'cough',
#    'catch',
#    'scent',
#    'really',
#    'kill',
#    'throat',
#    'people',
#    'ask',
#    'cough',
#    'neck',
#    'arm',
#    'hand',
#    'burn',
#    'hot',
#    'skin',
#    'bleed',
#    'blistering',
#    'allergic',
#    'reaction',
#    'makeup',
#    'wear',
#    'scream',
#    'pain',
#    'hurry',
#    'sink',
#    'wash',
#    'makeup',
#    'fast',
#    'possible',
#    'wash',
#    'neck',
#    'slowly',
#    'warm',
#    'water',
#    'turn',
#    'hot',
#    'burn',
#    'arm',
#    'hand',
#    'greatly',
#    'stop',
#    'cry',
#    'stinging',
#    'pain',
#    'quickly',
#    'switch',
#    'cold',
#    'water',
#    'soothe',
#    'pain',
#    'slightly',
#    'dad',
#    'watch',
#    'happen',
#    'cry',
#    'beg',
#    'pain',
#    'stop',
#    'mom',
#    'rush',
#    'help',
#    'finally',
#    'wake',
#    'hospital',
#    'burn',
#    'mostly',
#    'tell',
#    'still',
#    'raw',
#    'parent',
#    'check',
#    'hospital',
#    'wait',
#    'dreary',
#    'medically',
#    'green',
#    'room',
#    'corporal',
#    'green',
#    'waiting',
#    'room',
#    'small',
#    'child',
#    'walk',
#    'top',
#    'head',
#    'completely',
#    'flat',
#    'skull',
#    'half',
#    'develop',
#    'gladly',
#    'play',
#    'really',
#    'play',
#    'nobody',
#    'really',
#    'play',
#    'way',
#    'respond',
#    'well',
#    'swell',
#    'kiddo',
#    'beam',
#    'mom',
#    'return',
#    'check',
#    'hospice',
#    'child',
#    'playing',
#    'play',
#    'people',
#    'play',
#    'due',
#    'condition',
#    'respond',
#    'problem',
#    'sweet',
#    'kid',
#    'say_goodbye',
#    'leave',
#    'sometime',
#    'later',
#    'wander',
#    'town',
#    'coast',
#    'brick',
#    'road',
#    'old',
#    'fashioned',
#    'lamp',
#    'brighten',
#    'way',
#    'foggy',
#    'sun',
#    'find',
#    'friend',
#    'mine',
#    'meet',
#    'hospital',
#    'believe',
#    'sister',
#    'child',
#    'deformity',
#    'ask',
#    'follow',
#    'rush',
#    'town',
#    'bridge',
#    'seabird',
#    'way',
#    'spot',
#    'doctor',
#    'check',
#    'small',
#    'child',
#    'deformity',
#    'sit',
#    'side',
#    'observe',
#    'asleep',
#    'mother',
#    'arm',
#    'doctor',
#    'point',
#    'small',
#    'child',
#    'head',
#    'small',
#    'crown',
#    'point',
#    'form',
#    'flat',
#    'area',
#    'top',
#    'head',
#    'progress',
#    'doctor',
#    'speak',
#    'progress',
#    'ask',
#    'flat',
#    'nodded',
#    'understanding',
#    'doctor',
#    'pack',
#    'leave',
#    'wave',
#    'goodbye',
#    'mother',
#    'sister',
#    'leave',
#    'way',
#    'hotel',
#    'parent',
#    'stay',
#    'floor',
#    'sink',
#    'wash',
#    'makeup',
#    'enter',
#    'hallway',
#    'room',
#    'dad',
#    'ask',
#    'like',
#    'burger',
#    'hotdog',
#    'choose',
#    'hotdog',
#    'car',
#    'remember',
#    'ask',
#    'walk',
#    'room',
#    'proceed',
#    'car',
#    'first',
#    'walk',
#    'sink',
#    'wash',
#    'mirror',
#    'something',
#    'hand',
#    'sink',
#    'something',
#    'feel',
#    'soap',
#    'pay',
#    'mind',
#    'soap',
#    'corner',
#    'smell',
#    'scent',
#    'makeup',
#    'soap',
#    'rush',
#    'sink',
#    'terrify',
#    'hand',
#    'burn',
#    'wash',
#    'wake',
#    'bed',
#    'real',
#    'life',
#    'neck',
#    'arm',
#    'hand',
#    'burn'],
#   ['pretty',
#    'normal',
#    'store',
#    'work',
#    'school',
#    'ill',
#    'interact',
#    'someone',
#    'really',
#    'quick',
#    'gumball',
#    'machine',
#    'little',
#    'girl',
#    'quarter',
#    'gumball',
#    'stop',
#    'spin',
#    'machine',
#    'stuck',
#    'watch',
#    'someone',
#    'something',
#    'soup',
#    'pen',
#    'answer',
#    'repeat',
#    'wake',
#    'sweat',
#    'example',
#    'write',
#    'paper',
#    'guy',
#    'date',
#    'date',
#    'problem',
#    'date',
#    'date',
#    'problem',
#    'realize',
#    'restart',
#    'anyone_else',
#    'usual',
#    'nightmare',
#    'frequent',
#    'recently',
#    'tldr',
#    'nightmare',
#    'basically',
#    'stuck',
#    'gif',
#    'freak',
#    'happen',
#    'frequently'],
#   ['float',
#    'river',
#    'people',
#    'cry',
#    'explain',
#    'friend',
#    'drown',
#    'river',
#    'cross',
#    'bridge',
#    'cross',
#    'labyrinth',
#    'rock',
#    'touch',
#    'civilisation',
#    'advanced',
#    'technology',
#    'term',
#    'calculate',
#    'time',
#    'wooden',
#    'palace',
#    'overlook',
#    'mount',
#    'kailash',
#    'perlin',
#    'wooden',
#    'floor',
#    'project',
#    'balcony',
#    'bath',
#    'sun',
#    'wind',
#    'blow',
#    'snow',
#    'top',
#    'mountain',
#    'feel',
#    'overwhelmed',
#    'wonderful',
#    'ever',
#    'paint',
#    'sure'],
#   ['year',
#    'maybe',
#    'never',
#    'remember',
#    'something',
#    'wrong',
#    'remember',
#    'always',
#    'end',
#    'jump',
#    'damn',
#    'cliff',
#    'escape',
#    'crave',
#    'dull',
#    'life',
#    'live'],
#   ['last_night',
#    'art',
#    'supply',
#    'storeeven',
#    'though',
#    'artboi',
#    'reason',
#    'geography',
#    'teacher',
#    'store',
#    'store',
#    'qte',
#    'show',
#    'screen',
#    'suddenly',
#    'teleport',
#    'public',
#    'bathroom',
#    'cousin',
#    'brother',
#    'mom',
#    'teacher',
#    'tour',
#    'bathroom',
#    'head',
#    'outside',
#    'turn',
#    'mall',
#    'tall',
#    'one',
#    'head',
#    'escalator',
#    'reason',
#    'hang',
#    'side',
#    'teleport',
#    'game',
#    'nioh',
#    'specifically',
#    'battle',
#    'friendwell',
#    'call',
#    'game',
#    'almost',
#    'kill',
#    'teleport',
#    'rubiks_cube',
#    'world',
#    'rubiks',
#    'cube',
#    'floor',
#    'white',
#    'grey',
#    'tile',
#    'bounce',
#    'white',
#    'tile',
#    'die',
#    'whole',
#    'rubiks_cube',
#    'thing',
#    'still',
#    'transport',
#    'audience',
#    'sort',
#    'projector',
#    'screen',
#    'show',
#    'rubiks',
#    'cube',
#    'rubiks_cube',
#    'world',
#    'fail',
#    'bounce',
#    'rubiks',
#    'cub',
#    'screen',
#    'inaudience',
#    'die',
#    'really',
#    'worried',
#    'outta',
#    'nowhere',
#    'jammy',
#    'nutron',
#    'family',
#    'show',
#    'place',
#    'act',
#    'cool',
#    'stuff',
#    'sudden',
#    'transport',
#    'art',
#    'supply',
#    'store',
#    'mention',
#    'earlier',
#    'qt',
#    'someone',
#    'explain'],
#   ['recur',
#    'character',
#    'wonder',
#    'mean',
#    'anything',
#    'example',
#    'monty',
#    'burn',
#    'simpson',
#    'always',
#    'act',
#    'role',
#    'model',
#    'mentor',
#    'first',
#    'appearance',
#    'grade',
#    'teach',
#    'wash',
#    'face',
#    'hide',
#    'scent',
#    'mannequin',
#    'long',
#    'story',
#    'balloon',
#    'parent',
#    'red',
#    'balloon',
#    'green',
#    'blue',
#    'balloon',
#    'act',
#    'parental',
#    'figure',
#    'first',
#    'appearance',
#    'grade',
#    'adopt',
#    'balloon',
#    'year',
#    'tell',
#    'story',
#    'reject',
#    'learn',
#    'love',
#    'mourn',
#    'death',
#    'last',
#    'appearance',
#    'grade',
#    'promise',
#    'minigolfing',
#    'leak',
#    'die',
#    'sad',
#    'still',
#    'give',
#    'nostalgic',
#    'sadness',
#    'thinking',
#    'today',
#    'deceased',
#    'grandma',
#    'always',
#    'act',
#    'useless',
#    'side',
#    'character',
#    'first',
#    'appearance',
#    'alien',
#    'invasion',
#    'shortly_after',
#    'stay',
#    'house',
#    'grade',
#    'worth_not',
#    'dad',
#    'treatment',
#    'drive',
#    'away',
#    'friend',
#    'expiry',
#    'fourth',
#    'grade',
#    'stop',
#    'show',
#    'freshman',
#    'year',
#    'high_school',
#    'aunt',
#    'favorite',
#    'aunt',
#    'die',
#    'terminal',
#    'illness',
#    'sad',
#    'time',
#    'worth_not',
#    'perfectly',
#    'healthy',
#    'brotheract',
#    'character',
#    'save',
#    'everything',
#    'car',
#    'accident',
#    'witch',
#    'attack',
#    'actual',
#    'parent',
#    'exist',
#    'disappear',
#    'put',
#    'brother',
#    'predicament',
#    'act',
#    'deus',
#    'machina',
#    'mannequin',
#    'faceless',
#    'horde',
#    'act',
#    'bystander',
#    'antagonist',
#    'likely',
#    'placeholder',
#    'unspeakable',
#    'horror',
#    'puppeteer',
#    'final',
#    'boss',
#    'factory',
#    'evil',
#    'witch',
#    'form',
#    'entity',
#    'main',
#    'antagonist',
#    'penguin',
#    'madagascar',
#    'recur',
#    'gag',
#    'penguin',
#    'madagascar',
#    'blow',
#    'moon',
#    'anyone',
#    'potential',
#    'explanation',
#    'recur',
#    'character',
#    'represent'],
#   ['pissed',
#    'recently',
#    'dreamsold',
#    'buddy',
#    'pay',
#    'buck',
#    'owe',
#    'perfect',
#    'woman',
#    'revisit',
#    'disneyland',
#    'time',
#    'really',
#    'worry',
#    'feel',
#    'drop',
#    'acid',
#    'sum',
#    'similar',
#    'always',
#    'pissed',
#    'wake',
#    'btw'],
#   ['past',
#    'few_day',
#    'crush',
#    'girl',
#    'friend',
#    'tell',
#    'way',
#    'date',
#    'someone',
#    'else',
#    'become',
#    'kinda',
#    'sorta',
#    'friend',
#    'pretty',
#    'uneasy',
#    'various',
#    'point',
#    'always',
#    'drop',
#    'hint',
#    'girl',
#    'unsuccessfully'],
#   ['keep',
#    'dancer',
#    'long',
#    'story',
#    'short',
#    'dance',
#    'world',
#    'toxic',
#    'place',
#    'leave',
#    'negative',
#    'circumstance',
#    'nearly',
#    'years_ago',
#    'initially',
#    'bitterness',
#    'really',
#    'pop',
#    'past',
#    'month',
#    'confusing',
#    'really',
#    'distressing',
#    'keep',
#    'still',
#    'dance',
#    'usually',
#    'studio',
#    'wish',
#    'quit',
#    'leave',
#    'behind',
#    'negativity',
#    'bring',
#    'never',
#    'exactly',
#    'always',
#    'revolve',
#    'wish',
#    'leave',
#    'emotion',
#    'strong',
#    'wake',
#    'confuse',
#    'urgent',
#    'feeling',
#    'act',
#    'realize',
#    'brain',
#    'fog',
#    'fade',
#    'away',
#    'quit',
#    'mean',
#    'frequently'],
#   ['basically',
#    'town',
#    'people',
#    'really',
#    'person',
#    'swim',
#    'river',
#    'tunnel',
#    'lead',
#    'water',
#    'slide',
#    'thing',
#    'bunch',
#    'different',
#    'way',
#    'person',
#    'stop',
#    'stay',
#    'still',
#    'hop',
#    'lose',
#    'turn',
#    'correct',
#    'way',
#    'town',
#    'lobby',
#    'bunch',
#    'door',
#    'room',
#    'bunch',
#    'people',
#    'fucking',
#    'orgy',
#    'shit',
#    'join',
#    'dude',
#    'fuck',
#    'dick',
#    'popsicle',
#    'stick',
#    'fuck',
#    'popsicle',
#    'stick',
#    'dude',
#    'cum',
#    'rubber',
#    'glove',
#    'dick',
#    'wake',
#    'turn',
#    'part',
#    'real',
#    'walk',
#    'orgy',
#    'actually',
#    'leave',
#    'sleep',
#    'random',
#    'person',
#    'bed',
#    'room',
#    'people',
#    'catch',
#    'random',
#    'bed',
#    'leave',
#    'suppose',
#    'room',
#    'bunch',
#    'cat',
#    'people',
#    'panic',
#    'weather',
#    'pregnant',
#    'fuck',
#    'completely',
#    'forget',
#    'happend',
#    'wait',
#    'post'],
#   ['hand',
#    'last_night',
#    'white',
#    'woman',
#    'find',
#    'middle',
#    'terrorist',
#    'attack',
#    'mall',
#    'cheesy',
#    'oneliner',
#    'pull',
#    'grenade',
#    'launcher',
#    'bystander',
#    'next',
#    'turn',
#    'face',
#    'terrorist',
#    'exactly',
#    'identical',
#    'black',
#    'woman',
#    'answer',
#    'kill',
#    'first',
#    'ammunition',
#    'shot',
#    'second',
#    'woman',
#    'attack',
#    'trap',
#    'room',
#    'whip',
#    'grenade',
#    'launcher',
#    'turn',
#    'shoot',
#    'smoke',
#    'grenade',
#    'actual',
#    'grenade',
#    'adversary',
#    'prepare',
#    'shoot',
#    'shot',
#    'smoke',
#    'grenade',
#    'throat',
#    'kill',
#    'last',
#    'hide',
#    'raise',
#    'cane',
#    'detonate',
#    'bomb',
#    'second',
#    'floor',
#    'mall',
#    'jump',
#    'railing',
#    'fiery',
#    'blast',
#    'speed',
#    'disembody',
#    'voice',
#    'proclaim',
#    'physics',
#    'fact',
#    'day',
#    'explosion',
#    'travel',
#    'downwards',
#    'true',
#    'end',
#    'break',
#    'bone',
#    'body',
#    'last',
#    'memory',
#    'watch',
#    'avatar',
#    'third',
#    'person',
#    'wheel',
#    'team',
#    'flash',
#    'thumbsup',
#    'sign',
#    'first',
#    'kind',
#    'couple',
#    'month',
#    'catgirl',
#    'fascist',
#    'ninjawizard',
#    'oversee',
#    'hostage',
#    'exchange',
#    'catgirl',
#    'fascist',
#    'ninjawizard',
#    'ridiculous',
#    'middle',
#    'school',
#    'day',
#    'somehow',
#    'resurface',
#    'wear',
#    'green',
#    'beret',
#    'white',
#    'muscle',
#    'shirt',
#    'green',
#    'pant',
#    'metal',
#    'boot',
#    'kick',
#    'machete',
#    'shivv',
#    'special',
#    'ability',
#    'convert',
#    'kinetic',
#    'energy',
#    'physical',
#    'attack',
#    'explosion',
#    'important',
#    'later',
#    'bodyguard',
#    'oversee',
#    'hostage',
#    'exchange',
#    'bodyguard',
#    'guess',
#    'shitty',
#    'kitsune',
#    'shoot',
#    'explosion',
#    'hostage',
#    'exchange',
#    'place',
#    'supermarket',
#    'plain',
#    'sight',
#    'place',
#    'sour',
#    'push',
#    'shopping',
#    'cart',
#    'party',
#    'kitsune',
#    'recommend',
#    'thing',
#    'transform',
#    'ball',
#    'light',
#    'zip',
#    'supermarket',
#    'accomplish',
#    'jack',
#    'shit',
#    'guy',
#    'party',
#    'shoot',
#    'kitsune',
#    'fuck',
#    'dropkick',
#    'cause',
#    'explosion',
#    'big',
#    'enough',
#    'kill',
#    'keenly',
#    'aware',
#    'cringy',
#    'goosestepp',
#    'measure',
#    'skull',
#    'love',
#    'interest',
#    'love',
#    'moment',
#    'watch',
#    'anime',
#    'video',
#    'bedtime',
#    'cause'],
#   ['handful',
#    'lucid',
#    'particular',
#    'instance',
#    'almost',
#    'become',
#    'lucid',
#    'share',
#    'first',
#    'ever',
#    'lucid',
#    'probably',
#    'vivid',
#    'one',
#    'ever',
#    'years_ago',
#    'ever',
#    'forget',
#    'begin',
#    'sister',
#    'dark',
#    'shallow',
#    'grotto',
#    'ton',
#    'blue',
#    'fluorescent',
#    'flower',
#    'fungus',
#    'avatar',
#    'much',
#    'small',
#    'night',
#    'float',
#    'pond',
#    'bellyup',
#    'small',
#    'dogfishshark',
#    'begin',
#    'approach',
#    'somehow',
#    'shark',
#    'lightly',
#    'graze',
#    'able',
#    'tell',
#    'giant',
#    'shark',
#    'often',
#    'kid',
#    'scar',
#    'irl',
#    'reason',
#    'world',
#    'always',
#    'induce',
#    'fearanxiety',
#    'immediately',
#    'realize',
#    'become',
#    'lucid',
#    'ever',
#    'transport',
#    'grotto',
#    'bedroom',
#    'cloudy',
#    'outside',
#    'room',
#    'dimly_lit',
#    'room',
#    'normal',
#    'part',
#    'fact',
#    'little',
#    'quirky',
#    'object',
#    'surface',
#    'able',
#    'examine',
#    'vivid',
#    'detail',
#    'particular',
#    'object',
#    'remember',
#    'palmsiz',
#    'mario',
#    'mushroom',
#    'lightly',
#    'bob',
#    'backandforth',
#    'fluorescent',
#    'mushroom',
#    'grotto',
#    'earlier',
#    'bedroom',
#    'window',
#    'realize',
#    'cloudy',
#    'tiny',
#    'storm',
#    'manifest',
#    'backyard',
#    'stormcloud',
#    'lighting',
#    'shoot',
#    'directly',
#    'amalgamation',
#    'work',
#    'traffic',
#    'light',
#    'whose',
#    'cable',
#    'become',
#    'tangle',
#    'giant',
#    'mass',
#    'spend',
#    'portion',
#    'turn',
#    'head',
#    'away',
#    'window',
#    'time',
#    'configuration',
#    'traffic',
#    'light',
#    'mass',
#    'reassemble',
#    'different',
#    'configuration',
#    'finally',
#    'bore',
#    'venture',
#    'closet',
#    'transport',
#    'forest',
#    'similar',
#    'grotto',
#    'earlier',
#    'time',
#    'watch',
#    'third',
#    'person',
#    'instead',
#    'become',
#    'rogue',
#    'elf',
#    'character',
#    'world',
#    'warcraft',
#    'spend',
#    'rest',
#    'oneshott',
#    'hostile',
#    'enemy',
#    'head',
#    'perfect',
#    'accuracy',
#    'leap',
#    'heart',
#    'content',
#    'wake'],
#   ['last',
#    'summer',
#    'drive',
#    'country',
#    'really',
#    'day',
#    'corn',
#    'field',
#    'gravel',
#    'road',
#    'around',
#    'really',
#    'pretty',
#    'abandon',
#    'building',
#    'hotel',
#    'something',
#    'pull',
#    'picture',
#    'picture',
#    'behind',
#    'sky',
#    'dark',
#    'inside',
#    'shelter',
#    'long',
#    'story',
#    'short',
#    'ever',
#    'die',
#    'demon',
#    'thing',
#    'keep',
#    'pop',
#    'scar',
#    'shit',
#    'entire',
#    'consist',
#    'constant',
#    'jump',
#    'scare',
#    'lol',
#    'thing',
#    'kill',
#    'time',
#    'different',
#    'part',
#    'building',
#    'keep',
#    'kill',
#    'control',
#    'lucid',
#    'alot',
#    'anywho',
#    'month',
#    'later',
#    'boyfriend',
#    'drive',
#    'iowa',
#    'pick',
#    'dog',
#    'adopt',
#    'minnesota',
#    'never',
#    'iowa',
#    'drive',
#    'middle',
#    'nowhere',
#    'country',
#    'gravel',
#    'road',
#    'corn',
#    'field',
#    'window',
#    'sudden',
#    'guess',
#    'exact',
#    'building',
#    'mouth',
#    'drop',
#    'open',
#    'honestly',
#    'confused',
#    'much',
#    'shock',
#    'word',
#    'tell',
#    'pull',
#    'picture',
#    'find',
#    'word',
#    'bizarre',
#    'weird',
#    'stuff',
#    'wise',
#    'happen',
#    'stuff',
#    'never',
#    'real',
#    'life',
#    'example',
#    'movie',
#    'dejavu',
#    'never',
#    'movie',
#    'never',
#    'trailer',
#    'nothing',
#    'yet',
#    'month',
#    'movie',
#    'ever',
#    'detail',
#    'layout',
#    'basement',
#    'movie',
#    'weird',
#    'middle',
#    'nowhere',
#    'crazy',
#    'lol'],
#   [],
#   ['probably',
#    'realistic',
#    'life',
#    'everything',
#    'feel',
#    'real',
#    'pain',
#    'pleasure',
#    'type',
#    'person',
#    'always',
#    'distinguished',
#    'shit',
#    'scary',
#    'hell',
#    'first',
#    'control',
#    'manage',
#    'travel',
#    'place',
#    'place',
#    'experience',
#    'thing',
#    'something',
#    'amiss',
#    'happen',
#    'person',
#    'suddenly',
#    'ask',
#    'borrow',
#    'body',
#    'reason',
#    'thing',
#    'happen',
#    'false_awaken',
#    'left',
#    'realize',
#    'weird',
#    'weirder',
#    'sudden',
#    'blackout',
#    'second',
#    'tell',
#    'body',
#    'place',
#    'place',
#    'freak',
#    'hell',
#    'place',
#    'keep',
#    'black',
#    'forget',
#    'guy',
#    'ask',
#    'body',
#    'search',
#    'fix',
#    'thing',
#    'able',
#    'manage',
#    'open',
#    'youtube',
#    'discord',
#    'everything',
#    'order',
#    'last',
#    'thing',
#    'finally',
#    'sense',
#    'people',
#    'tell',
#    'something',
#    'amiss',
#    'suddenly',
#    'act',
#    'face',
#    'suddenly',
#    'bit',
#    'red',
#    'soon',
#    'finally',
#    'remember',
#    'guy',
#    'manage',
#    'erase',
#    'last',
#    'manage',
#    'body',
#    'reason',
#    'truly',
#    'able',
#    'wake',
#    'thing',
#    'still',
#    'scary',
#    'hell'],
#   ['house',
#    'plot',
#    'land',
#    'around',
#    'really',
#    'different',
#    'reason',
#    'mom',
#    'sell',
#    'fencing',
#    'chicken',
#    'sister',
#    'fence',
#    'keep',
#    'chicken',
#    'lock',
#    'tiny',
#    'coop',
#    'herd',
#    'keep',
#    'yard',
#    'giant',
#    'chicken',
#    'coop',
#    'giant',
#    'mean',
#    'bunch',
#    'different',
#    'room',
#    'house',
#    'small',
#    'grassy',
#    'area',
#    'floor',
#    'basically',
#    'house',
#    'chicken'],
#   ['first',
#    'call',
#    'calamity',
#    'huge',
#    'dust',
#    'cloud',
#    'engulf',
#    'world',
#    'kill',
#    'anyone',
#    'contact',
#    'next',
#    'mill',
#    'finally',
#    'recently',
#    'end',
#    'second',
#    'everything',
#    'normal',
#    'instant',
#    'world',
#    'cease',
#    'exist',
#    'keep',
#    'anyone_else',
#    'similar',
#    'issue',
#    'keep',
#    'world',
#    'end'],
#   ['long',
#    'remember',
#    'place',
#    'live',
#    'kid',
#    'maybe',
#    'wake',
#    'window',
#    'picture',
#    'drawing',
#    'idea',
#    'sky',
#    'full',
#    'ufos',
#    'move',
#    'formation',
#    'mountain',
#    'keep',
#    'end',
#    'recur',
#    'often',
#    'picture'],
#   ['walk',
#    'gallery',
#    'huge',
#    'wall',
#    'left',
#    'front',
#    'cover',
#    'hundred',
#    'small',
#    'blurry',
#    'painting',
#    'walk',
#    'wall',
#    'front',
#    'huge',
#    'glow',
#    'clear',
#    'painting',
#    'middle',
#    'archangel',
#    'michael',
#    'michael',
#    'wake'],
#   ['sex',
#    'actor',
#    'show',
#    'lucifer',
#    'actually',
#    'lucifer',
#    'sex',
#    'transform',
#    'animal',
#    'pig',
#    'cat',
#    'bird',
#    'fighter',
#    'fish',
#    'note',
#    'research',
#    'fighter',
#    'fish',
#    'mate',
#    'bed',
#    'single',
#    'year',
#    'night',
#    'alone'],
#   ['often',
#    'sleep_paralysis',
#    'vivid',
#    'sometimes',
#    'terrifying',
#    'occasional',
#    'day',
#    'nap',
#    'car',
#    'trouble',
#    'decipher',
#    'flash',
#    'white',
#    'background',
#    'people',
#    'face',
#    'snort',
#    'white',
#    'powder',
#    'least',
#    'different',
#    'people',
#    'face',
#    'pop',
#    'cut',
#    'child',
#    'walk',
#    'childhood',
# ...
#   'lately yell people fighting dare anyone challenge fuck weird completely fine real life mad anything recently',
#   '',
#   'first post reddit mobile weird friend house group sleepover never people real life host donna show actual name donna point decide great idea summon demon shit sit point pentagram sit inbetween circle whoopla sit concern chant anything venom creature rise ground attack people hide closet kill everyone find kill wake closet around empty eerily quiet find stuff hell find stuff shoe creep house creature still donna find flip house explain happen freak give old pair shoe leave idea dog super friendly menacing bark crazy menacing dog thought home avoid chain long bite avoid bit ahead something feel grab phone text fiance ask pick date something remember exact date freak first reaction happen fiance baby exist anymore really sad open phone lock figure password anxiety attack afraid happen technically new something cry fiance together tell ill find ill spark relationship cross mind maybe remember maybe bond beat time daughter month fade away sad happy walk point sidewalk shitty old shitty abandon factory leave train track moment happy family already wake realize instant relief already appreciate life appreciate life sure exactly deep meaning idea brain',
#   'night remember completely black human shape figure perch top shelf bedroom remember everything room detailed really dark figure street light peer window couple night later figure stand middle room next night stand next bed body bed move night different time inside remember immediately wake able move speak yell sleep_paralysis assume last_night bad remember living room water waist dead child float water woman presume dead well quickly star eye suddenly outside house walk inside stop door body bend way imagine kind like possess actually almost exactly expect someone possess move force face keep slam pavement woke vividly remember pain feel vivid detail simply remember time soon wake forward anyone idea mean update anything new occur',
#   'remember tab computer video sex really hot girl recollection perform defiantly screen waking super trippy still virgin high_school sophomore odd type scenario let alone porn video',
#   'couple nights_ago bother shop grocery_store angry man approach baby arm babys face appear deform man tell fix baby remember possible meaning',
#   'seriously weird ever family cat montana vacation irl vacation montana sister great time remember eat restaurant together head airport airport security realize forget bring bag bag irl boyfriend professor way security tell airport staff bag sit room glass wall hour wait someone bring room kinda box seat huge arena set like story area concrete feel prison people put kind show wait balcony room watch sit room instead eat ton banana family contact time figure flight eventually break arena find bring cat realize somehow bag along leave able tho instead stay watch show perform arena watch people box seat balcony fall assume mass suicide freak notice min later floor balcony tilt people fall grab wall balcony able room reason realize someone box control irl childhood friend mom realize figure tilt box fall sister boyfriend kill break room point cat sick injure something different irl childhood friend mom happen weird airport arena set treat cat everything fine cat turn bright purple realize forget stop draw cat blood cat lose blood almost die reason refuse pay friend mom treatment mom step yell friend mom pay friend mom freak storm return min later knife blood already entire vet staff show nowhere help defeat kill cat box seat room tell never notice end friend college hide room leave whatev weapon find find knit needle lmao vet staff wake point occur hour nap idea super freak brain anyway long reading let thought whatev thanks_advance',
#   'precise problem school smoke toilet set smoke alarmi retartedlater lie parent night feel urge passionately pull tooth sleep entire night advice help',
#   'friend city discover cavern red cream building enter place find cavern huge desert mountain oasis first time dark mountain find entrance huge temple temple sewer puzzle maze cross river temple friend disappear walk find guy rescue earthquake temple escape second time cavern sunny sun cavern black sphere center enter temple find friend almost escape temple fill water sand friend rescue thing ask pray god temple feel drown water sand feel pain chest breath almost dead reappear entrance cavern mountain',
#   'reoccurr vivid almost nightly terminator terminator keep year old version keep away hiding location anticipation bust door time barely away basically connor terminator deep hell subconscious',
#   'anyone ever hurt wake actually hurt',
#   '',
#   'serious post bug idea mean must follower political event care less odd give dam russia whatev however past week ocassion putin show remember remember first cool tree house play video_game air hockey putin literally hang today putin feel presence search honestly bit scared woke feeling drained energy troll post earth vladimir putin showing',
#   'always really weird vivid last_night pregnant gave_birth tiny guess human thing boyfriend awkwardly propose front dad department store pick ring spin jewelry display awkward later end tell marry baby still end leave gave_birth store carry small box apparently whatev immersed water shrivel die guess late somehow still alive point hop dead scared life child friend pick heshe kind gross dog sudden jump friend arm hold baby slice artery neck dead walk pitiful way terrify frankenstein monster way leg almost detach end mean anything strange almost sense',
#   'ever little boy specifically nightmare old woman tickle non stop mean sound crazy true normal sudden old woman tickle mind first few_second feel uncomfortable point cry feel really uncomfortable people always avoid physical contact ability forward later life',
#   'sort rule notice general something happen real life accident accept show happen someone way usually put big plot behind example real life infection finger size heal properly pull left scar month however show sort demonic turtle attack bite finger time burn hand accident hotplate burn big deal however show dark dungeon room monster wear armour decide jump fry pan burn alive describe body burn feel eye blind fun finish style century guess forum thing one woman lose child turn doctor secretly kill child thing infertility evil doctor time real life break houseplant accident tall urgent plant surgery save actually houseplant cat like near much actually sit accident sit break leg break houseplant accident almost cat plant fault near much obviously dangerous point well point show really cool stuff fun way makes_sense meaningful always rule nothing bad happen accident someone choose way bad warn listen still choice write reallife story mean fictionwriter someone write plot computergame film thing happen accident disease happen accident birth defect happen accident disadvantage life accident abusive parent bully school reason plot behind stop perhaps choose suffer way someone choose maybe help write fun deep plotline story general people believe true example myth bad thing winter happen accident happen someone powerful demigod way angry something god cause winter argument kind bad myth honest orbit sun stuff winter still interesting story sure story made fit physics consider people really deep powerful plotline explain sort thing far complicated winter sure someone explanation god angry else angry year time stupid physics base event mean interpret way',
#   'mom move original home expensive find cheap place sister live place move weird pas room roomapartment small depressing door basically lock anything literally move room house hotel recall correctly door proper lock dark depressing inside single window beautiful view bright beach shore curve crescent moon water bright blue mom cheer point beautiful view still miss view city skyscraper beach beautiful course feel place desperate remember basic thing sit living room old house normal thing really sad eventually sit mother sit next verge tear ask wrong sob end hour still depress feel real feel despair build cry hold tear still pretty weird considering position move rent much nothing else indicate anything similar nothing indicative something',
#   'titlemy skip like bad write story part sense skip kinda unrelated title thing happen different character game happen imagination sleep leave anyway rid maybe lucid case imaginat sexbend situation fetish suddenly asleep guy cosplay situation action hitman game normal download yesterday suddenly thing weird remember meet random girl suddenly become friend tldremember happen suddenly samus aran remember feeling power suit maybe lately play around game time random guy tell trap kind loop throgh beat kind guy group guy point continue finish relatively short time wake',
#   'town grow talk parent tell beautiful girl live pregnant time lose child unexplained circumstance ask marry feel depressed nothing live reluctant first mind girl end agree marry thing little weird worried dick small happy small dick add emphasis size dick past end marry marry year pregnant first child guess die obviously remember lose investigate dig deep life maybe curse maybe someone lose child later find doctor fucker name pietro exactly albert einstein life one give pill sickness fact lose child turn guy rap pregnant kill fetus discover find sort sick enjoyment moment onwards time patient include fake wife pregnant kill child gather witness jail year live minecraft ass glass house supposedly build top tree forest scotland basically glass tree house pregnant time daughter actually bear reason decide name pietra honor guy kill rest sibling lmao end wife pietra sit top glass house firework distance wake',
#   'doubt strange ever bullshit title thing remember bar bite cheek push away wtf man sleep mom yea apparently blade sleep mom',
#   'fault something last night accuse murder girl suppose give death penalty mere day thing nobody believe search everywhere evidence show innocent mom keep cry detective charge case keep demotivate insist already guilty leave scar still die end manage find couple screwdriver somehow prove innocent apparently late tell screwdriver show innocence still die late desperately believe aid evidence indeed late apparently feel guilty something seek punishment subconscious',
#   'work front desk recreation facility real life last_night work woman husband kid ask purchase ticket day pass woman ask snippy tone allow point area behind really confused explain nothing area fun customer allow office space woman extremely frustrated pay ticket able access everything offer explain area fact offer spend time angry tell kid area anyways play remember angry cry woman kid range year old pile front desk mess paper office supply around keep thing organize last thing remember old child smirk pry stapler key hand nightmare inner self express dislike pushy customer',
#   'final major project nightmare really appreciate complete survey research question massive help link',
#   'time remember sometimes last night vivid search giant fish ocean ocean bed side bed small window top bed ocean fish hammer head shark head wide side body long red yellow color blueish stripe find fish side bed decide lift window top bed big snapping turtle mattress push keep bite remember yell mom something close window turtle longer anyone mean confused like little insight meaning',
#   'remember whole remember event concern close friend remember car something hug lean really affectionate watch movie close friend somehow morph someone else realize waking watch movie large room projector sit plastic chair close people class include guy year remember notice real life eat sort rock candy bowl disgusting event struggle binge eating eat much time stop feel really gross psychologically physically home sister puke large plastic cup reason realize vomit later drink obviously disgusting event coincidence wake morning minute later sleep disgusting cut fruit marble forget clean huge mess morning clean really clumsily throw bunch mineral water fail cockroach cookie jar drown throw mineral water top cleaning lady tell mess especially kill cockroach apparently die terrible odor grab napkin one jump hold feel squiggl around throw ground step bleed human blood top cleaning lady tell move corpse thankfully wake touch much coincidence find disgusting incest toilet anybody help uou',
#   'guy couple time strange feel almost different realm happen bedroom setting sleep impactful one truly confuse first happen years_ago stay lay sleep foggy state state bed man lay couch physical feature black figure energy lead feel talk panic suppose house parent wake soon tell stair door crack leave sleep basement eventually man bed follow suit foggy state realize minute weird last_night similar experience bit disorienting lay baby bed sleep sudden bed bathroom reason confuse sit bathroom finish feel really disoriented decide climb bed walk bed whole room spin grip feel uneasy bed continue sleep normal odd feel long wanted share anyone_else kind experience body present moment rather_than land never body feel real usual extremely vivid thanks_advance read hope hear experience',
#   'past night eye bug protrude head any_ideas mean',
#   'remember much time remember weird hell name brianna pretty quirky couple boyfriend kinda popular funny live kind add smart way like way like girl time maybe year old talk little bit loose remember something like ask wanna date reply never date future ask ball something remember time wanna date something corny possibly mean confused like add point time like like star minute kinda creepy attractive',
#   'finished education always well achieve top grade never unprepared thrive stress pressure exam deadline adult education much wake life frequently adult life recur point education school college university attend class complete assignment resit exam sometimes redo entire qualification class student much young always involve miss class really stressed overwhelmed realise completely forget suppose study sudden realisation work realise hopelessly behind anyone_else signify',
#   'regular friend music concert spot elevator elevator bar top floor apparently great view concert way big cockroach ever scuttle foot scream kick become paralysed moment hit wall decide stomp sure frighten lift shoe expect cockroach part mush bottom nothing cockroach body crust stand opposite corner elevator far away possible monstrosity body tear half still quite big cockroach crawl wall wake sweat reason hate cockroach second night bad watch youtube video abruptly change blue curtain screen large green box word find dory actually idea movie fit suddenly speaker house turn deal noise shotgun loading ring house goodness police family_member house second part video open file mac basically spam turn computer yet hold power button turn keyboard figure move next key keep happen eventually manage force quit file locate instantly delete later afternoon email unknown contact read share happen today afraid light tomorrow nothing morning tell mum wake really impact sleep schedule example currently write school today anyone fix tell sheer terror sleep',
#   'world thing somewhat parallel thing current life move new place new job lonelyanxious feel fit however different character different setting work talk girl coworker realize common become friend hold hand feel relief everything place live male roommate end warm laugh wake several time keep world hope thing well wake life give hope',
#   'never often ill store always different find rare video_game various series enjoy mean anything huge nerd',
#   '',
#   '',
#   ...])
